# %% [markdown]
# <a href="https://colab.research.google.com/github/wmusurya/Exploratory-Data-Analysis-on-the-Bike-Buyers-Dataset/blob/main/MAsters_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/OR_EV_Registrations.csv")
df
# Out:
#       State ZIP Code Registration Date Vehicle Make Vehicle Model  \
# 0        OR    97212          3/1/2022        TESLA       Model 3
# 1        OR    97450         12/1/2018        TESLA       Model 3
# 2        OR    97402         10/1/2022        TESLA       Model 3
# 3        OR    97225          8/1/2018        TESLA       Model 3
# 4        OR    97141          8/1/2022        TESLA       Model 3
# ...     ...      ...               ...          ...           ...
# 48819    OR    97229         11/1/2022          BMW            X5
# 48820    OR    97702         10/1/2022          BMW            X5
# 48821    OR    97403          4/1/2021    NEW FLYER      Xcelsior
# 48822    OR    98660         12/1/2019          NaN           NaN
# 48823    OR    97223         10/1/2022          NaN           NaN
#
#        Vehicle Model Year Drivetrain Type Vehicle GVWR Class  \
# 0                  2018.0             BEV                  1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48824 entries, 0 to 48823
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   State                     48824 non-null  object
#  1   ZIP Code                  48824 non-null  object
#  2   Registration Date         48824 non-null  object
#  3   Vehicle Make              48621 non-null  object
#  4   Vehicle Model             48621 non-null  object
#  5   Vehicle Model Year        48621 non-null  float64
#  6   Drivetrain Type           48621 non-null  object
#  7   Vehicle GVWR Class        48621 non-null  object
#  8   Vehicle Category          48621 non-null  object
#  9   Vehicle Count             48824 non-null  int64
#  10  DMV Snapshot (Date)       48824 non-null  object
#  11  DMV Snapshot ID           48824 non-null  int64
#  12  Latest DMV Snapshot Flag  48824 non-null  bool
# ...

# %%
df.head()
# Out:
#   State ZIP Code Registration Date Vehicle Make Vehicle Model  \
# 0    OR    97212          3/1/2022        TESLA       Model 3
# 1    OR    97450         12/1/2018        TESLA       Model 3
# 2    OR    97402         10/1/2022        TESLA       Model 3
# 3    OR    97225          8/1/2018        TESLA       Model 3
# 4    OR    97141          8/1/2022        TESLA       Model 3
#
#    Vehicle Model Year Drivetrain Type Vehicle GVWR Class  \
# 0              2018.0             BEV                  1
# 1              2018.0             BEV                  1
# 2              2018.0             BEV                  1
# 3              2018.0             BEV                  1
# 4              2018.0             BEV                  1
#
#           Vehicle Category  Vehicle Count        DMV Snapshot (Date)  \
# 0  Light-Duty (Class 1-2A)              1  DMV Snapshot (11/15/2022)
# 1  Light-Duty (Class 1-2A)              1  DMV Snapshot (11/15/2022)
# ...

# %%
df.shape
# Out:
# (48824, 13)

# %%
df.columns
# Out:
# Index(['State', 'ZIP Code', 'Registration Date', 'Vehicle Make',
#        'Vehicle Model', 'Vehicle Model Year', 'Drivetrain Type',
#        'Vehicle GVWR Class', 'Vehicle Category', 'Vehicle Count',
#        'DMV Snapshot (Date)', 'DMV Snapshot ID', 'Latest DMV Snapshot Flag'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                        object
# ZIP Code                     object
# Registration Date            object
# Vehicle Make                 object
# Vehicle Model                object
# Vehicle Model Year          float64
# Drivetrain Type              object
# Vehicle GVWR Class           object
# Vehicle Category             object
# Vehicle Count                 int64
# DMV Snapshot (Date)          object
# DMV Snapshot ID               int64
# Latest DMV Snapshot Flag       bool
# dtype: object

# %%
df.describe()
# Out:
#        Vehicle Model Year  Vehicle Count  DMV Snapshot ID
# count        48621.000000   48824.000000          48824.0
# mean          2018.455770       1.277568              1.0
# std              3.111701       1.236461              0.0
# min           1997.000000       1.000000              1.0
# 25%           2016.000000       1.000000              1.0
# 50%           2019.000000       1.000000              1.0
# 75%           2021.000000       1.000000              1.0
# max           2023.000000      86.000000              1.0

# %%
df.isna().sum()
# Out:
# State                         0
# ZIP Code                      0
# Registration Date             0
# Vehicle Make                203
# Vehicle Model               203
# Vehicle Model Year          203
# Drivetrain Type             203
# Vehicle GVWR Class          203
# Vehicle Category            203
# Vehicle Count                 0
# DMV Snapshot (Date)           0
# DMV Snapshot ID               0
# Latest DMV Snapshot Flag      0
# dtype: int64

# %%
Vehicle_Make_counts=df['Vehicle Make'].value_counts()
Vehicle_Make_counts
# Out:
# TESLA                                   12115
# CHEVROLET                                6266
# NISSAN                                   5627
# TOYOTA                                   4879
# FORD                                     3578
# BMW                                      2468
# KIA                                      2016
# HYUNDAI                                  2010
# VOLKSWAGEN                               1441
# VOLVO                                    1168
# AUDI                                     1111
# CHRYSLER                                  924
# HONDA                                     754
# FIAT                                      670
# JEEP                                      629
# SUBARU                                    588
# PORSCHE                                   387
# MERCEDES-BENZ                             354
# MITSUBISHI                                256
# SMART                                     236
# ...

# %%
Vehicle_GVWR_Class_counts=df['Vehicle GVWR Class'].value_counts()
Vehicle_GVWR_Class_counts
# Out:
# 1          43190
# 2           5348
# 2B            59
# 8              9
# 5              5
# 3              3
# Unknown        3
# 7              3
# 6              1
# Name: Vehicle GVWR Class, dtype: int64

# %%
df.plot(kind='scatter',
        x='Vehicle_GVWR_Class_counts',
        y='Drivetrain_Type_counts',
        title='Coaster Speed vs. Height')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vehicle_GVWR_Class_counts'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
ax = df['Vehicle GVWR Class'].value_counts(.1) \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle Make'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Vehicle Category'].value_counts()
# Out:
# Light-Duty (Class 1-2A)               48538
# Medium-Duty Vehicle (Class 2B - 6)       68
# Heavy-Duty Vehicle (Class 7-8)           12
# Unknown                                   3
# Name: Vehicle Category, dtype: int64

# %%
ax = df['Vehicle Category'].value_counts(100) \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
Drivetrain_Type_counts=df['Drivetrain Type'].value_counts()
Drivetrain_Type_counts
# Out:
# BEV     30239
# PHEV    18382
# Name: Drivetrain Type, dtype: int64

# %%
ax = df['Drivetrain Type'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Vehicle Model Year'].value_counts()
# Out:
# 2022.0    8700
# 2021.0    7832
# 2020.0    5209
# 2018.0    5136
# 2019.0    4927
# 2017.0    4511
# 2016.0    3305
# 2015.0    2662
# 2013.0    2361
# 2014.0    2047
# 2012.0    1124
# 2011.0     496
# 2023.0     125
# 2002.0      52
# 2001.0      28
# 2000.0      19
# 2008.0      19
# 2005.0      13
# 1998.0      12
# 2010.0      12
# 2007.0       8
# 2006.0       8
# 1999.0       5
# 1997.0       4
# 2003.0       3
# 2004.0       2
# 2009.0       1
# Name: Vehicle Model Year, dtype: int64

# %%
ax = df['Vehicle Model Year'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Latest DMV Snapshot Flag'].value_counts()
# Out:
# True    48824
# Name: Latest DMV Snapshot Flag, dtype: int64

# %%
df['Vehicle Model'].value_counts()
# Out:
# Leaf        5627
# Model 3     5186
# Model Y     2883
# Bolt EV     2848
# Volt        2729
#             ...
# R1S            1
# Asphalt        1
# Bentayga       1
# P1             1
# EDV            1
# Name: Vehicle Model, Length: 124, dtype: int64

# %%
ax = df['Vehicle Model'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Vehicle Model Year'].value_counts()
# Out:
# 2022.0    8700
# 2021.0    7832
# 2020.0    5209
# 2018.0    5136
# 2019.0    4927
# 2017.0    4511
# 2016.0    3305
# 2015.0    2662
# 2013.0    2361
# 2014.0    2047
# 2012.0    1124
# 2011.0     496
# 2023.0     125
# 2002.0      52
# 2001.0      28
# 2000.0      19
# 2008.0      19
# 2005.0      13
# 1998.0      12
# 2010.0      12
# 2007.0       8
# 2006.0       8
# 1999.0       5
# 1997.0       4
# 2003.0       3
# 2004.0       2
# 2009.0       1
# Name: Vehicle Model Year, dtype: int64

# %%
ax = df['Vehicle Model Year'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Vehicle GVWR Class'].value_counts()
# Out:
# 1          43190
# 2           5348
# 2B            59
# 8              9
# 5              5
# 3              3
# Unknown        3
# 7              3
# 6              1
# Name: Vehicle GVWR Class, dtype: int64

# %%
ax = df['Vehicle GVWR Class'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle GVWR Class'].value_counts(.1) \
    .head(10) \
    .plot(kind='kde', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle Make'].value_counts() \
    .head(10) \
    .plot(kind="kde", title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle Category'].value_counts(100) \
    .head(10) \
    .plot(kind='kde', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Drivetrain Type'].value_counts() \
    .head(10) \
    .plot(kind='kde', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle Model Year'].value_counts() \
    .head(10) \
    .plot(kind='kde', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle Model'].value_counts() \
    .head(10) \
    .plot(kind='kde', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle Model Year'].value_counts() \
    .head(10) \
    .plot(kind='kde', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Vehicle GVWR Class'].value_counts() \
    .head(10) \
    .plot(kind='kde', title='')
ax.set_xlabel('Car Brands')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.scatterplot(x='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-590ef8ca4a04> in <cell line: 1>()
# ----> 1 sns.scatterplot(x='')
#
# /usr/local/lib/python3.9/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# /usr/local/lib/python3.9/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# --> 538         super().__init__(data=data, variables=variables)
#     539
#     540         self.legend = legend
#
# ...
